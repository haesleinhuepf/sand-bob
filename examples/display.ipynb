# %%
from sand_bob import execute

# %%
res = execute("""
import numpy as np
import matplotlib.pyplot as plt

# Define the sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Create a range of x values
x_values = np.linspace(-10, 10, 100)

# Calculate the corresponding y values
y_values = sigmoid(x_values)

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the sigmoid curve on the axis
ax.plot(x_values, y_values)
ax.set_title('Sigmoid Function')
ax.set_xlabel('x')
ax.set_ylabel('sigmoid(x)')
ax.grid(True)

display(fig)
print(fig)
""", dependencies=["numpy", "matplotlib"])

# %%
res.files.keys()
# Out:
# dict_keys(['C:\\Users\\rober\\AppData\\Local\\Temp\\tmpo7ea3_bd\\display_output\\display_0.svg'])

# %%
from skimage.io import imread
from io import BytesIO
import stackview

byte_list = list(res.files.values())[0]  # Replace with your actual list of bytes
img = imread(BytesIO(bytes(byte_list)))
stackview.imshow(img)
# Out:
# C:\Users\rober\miniforge3\envs\genai-gpu\Lib\site-packages\imageio\core\util.py:508: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 6
#       3 import stackview
#       5 byte_list = list(res.files.values())[0]  # Replace with your actual list of bytes
# ----> 6 img = imread(BytesIO(bytes(byte_list)))
#       7 stackview.imshow(img)
#
# File ~\miniforge3\envs\genai-gpu\Lib\site-packages\skimage\_shared\utils.py:328, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     324     elif self.new_name is not None:
#     325         # Assign old value to new one
# ...

# %%
from IPython.display import display, SVG

# Convert the byte-stream to a BytesIO object
byte_stream = BytesIO(byte_list)

# Display the SVG image
svg_image = SVG(byte_stream.getvalue())
display(svg_image)
