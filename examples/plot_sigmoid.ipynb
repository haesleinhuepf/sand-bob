# %% [markdown]
# # Single code generation attempts
# If you _know_ that code generation from a specific prompt works in the vast majority of cases, you may want to execute code-generation once and go ahead to process the result. You can approach such scenarios like this:

# %%
from sand_bob import generate_code, config_scadsai_llm
config_scadsai_llm()

# %%
result = generate_code("Plot a sigmoid", dependencies=["numpy", "seaborn", "matplotlib"])
result.display_output()
# Out:
# <pre><pre>x shape: (400,)
# y shape: (400,)</pre><pre><matplotlib.legend.Legend at 0x7606d0111790></pre><p><img src='data:image/png;base64,...'/></p><pre>Plot of the sigmoid function defined on the interval [-10, 10].</pre><pre><Figure size 640x480 with 0 Axes></pre><pre>Saved PNG: /display_output/sigmoid_plot.png
# Saved SVG: /display_output/sigmoid_plot.svg</pre><pre>/display_output/sigmoid_plot.png, /display_output/sigmoid_plot.svg</pre></pre>

# %% [markdown]
# After execution, saved files are stored:

# %%
list(result.files.keys())
# Out:
# ['/display_output/notebook_executed.ipynb',
#  '/display_output/sigmoid_plot.png',
#  '/display_output/sigmoid_plot.svg']

# %% [markdown]
# One can access the byte arrays of the files like this:

# %%
result.files['/display_output/sigmoid_plot.svg']
# Out:
# b'<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\n  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" width="460.8pt" height="345.6pt" viewBox="0 0 460.8 345.6" xmlns="http://www.w3.org/2000/svg" version="1.1">\n <metadata>\n  <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\n   <cc:Work>\n    <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>\n    <dc:date>2026-05-23T10:38:28.617646</dc:date>\n    <dc:format>image/svg+xml</dc:format>\n    <dc:creator>\n     <cc:Agent>\n      <dc:title>Matplotlib v3.10.9, https://matplotlib.org/</dc:title>\n     </cc:Agent>\n    </dc:creator>\n   </cc:Work>\n  </rdf:RDF>\n </metadata>\n <defs>\n  <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>\n </defs>\n <g id="figure_1">\n  <g id="patch_1">\n   <path d="M 0 345.6 \nL 460.8 345.6 \nL 460.8 0 \nL 0 0 \nz\n" style="fill: #ffffff"/>\n  </g>\n </g>\n</svg>\n'
