# %%
from sand_bob import execute

# %%
# Execute code with GPU support
result = execute(
    code="import pyclesperanto_prototype as cle; print(cle.select_device('cupy')); print('hello world')",
    dependencies=["pyclesperanto-prototype", "cupy"],
    gpu_support=True
)

# %%
result
