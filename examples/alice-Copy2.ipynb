# %%
from sand_bob import initialize, config_kisski
config_kisski()
initialize(input_host_path="input_data/", n_parallel=5)

# %%
# %%alice
# in input_data/data.csv are two columns of independent samples.
# I would like to know if they are signifantly different
