# %% [markdown]
# # The `%%alice` magic command
# The `%%alice` magic command allows to generate code and store it a Jupyter Notebooks without a lot of boilerplate code.
# It is recommended though to initialize the environment, e.g. to define folders where alice should have access to or how many notebooks should be generated in parallel.
#
# **Note:** The GUI will not be rendered on Github, you need to execute this notebook to see it.

# %%
from sand_bob import initialize, config_scadsai_llm
config_scadsai_llm()

initialize(input_host_path="input_data/")

# %%
# %%alice
# Plot histograms of all columns in input_data/measurements.csv
# Out:
# <div id='sb-res-4b746ba82def490e9caec0d8f9eef8e6' class='sb-result-root'>
#
# <style>
# .sb-result-root {
#     --sb-border: #cfcfcf;
#     --sb-tab-bg: #f2f2f2;
#     --sb-tab-hover-bg: #ebebeb;
#     --sb-active-bg: #ffffff;
#     --sb-content-bg: #ffffff;
#     --sb-text: #2f2f2f;
#     --sb-shadow: rgba(0, 0, 0, 0.04);
#     margin-top: 8px;
#     color: var(--sb-text);
# }
#
# .sb-history-bar {
#     margin: 0 0 10px 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
# }
#
# .sb-history-label {
#     font-weight: 600;
#     font-size: 13px;
# }
#
# .sb-history-select {
#     min-width: 210px;
#     padding: 4px 8px;
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: #fff;
#     color: var(--sb-text);
# }
#
# .sb-history-panel {
#     margin: 0;
# }
#
# .sb-tabs {
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: var(--sb-content-bg);
#     box-shadow: inset 0 1px 0 var(--sb-shadow);
# }
#
# .sb-tab-buttons {
#     display: flex;
#     align-items: flex-end;
#     gap: 0;
#     border-bottom: 1px solid var(--sb-border);
#     background: linear-gradient(to bottom, #f8f8f8 0%, #f1f1f1 100%);
#     overflow-x: auto;
#     scrollbar-width: thin;
# }
#
# .sb-tab-btn {
#     appearance: none;
#     border: 0;
#     border-right: 1px solid #dddddd;
#     border-bottom: 1px solid var(--sb-border);
#     margin: 0;
#     background: var(--sb-tab-bg);
#     color: var(--sb-text);
#     padding: 7px 12px;
#     cursor: pointer;
#     font-size: 13px;
#     line-height: 1.25;
#     white-space: nowrap;
#     position: relative;
# }
#
# .sb-tab-btn:hover {
#     background: var(--sb-tab-hover-bg);
# }
#
# .sb-tab-btn.active {
#     background: var(--sb-active-bg);
#     font-weight: 600;
#     border-bottom: 1px solid var(--sb-active-bg);
#     box-shadow: inset 0 2px 0 #e6e6e6;
#     z-index: 1;
# }
#
# .sb-tab-content {
#     padding: 12px;
#     background: var(--sb-content-bg);
# }
#
# .sb-tab-panel {
#     display: none;
# }
#
# .sb-tab-panel.active {
#     display: block;
# }
#
# .sb-tab-content pre {
#     margin-top: 6px;
#     border: 1px solid #ececec;
# }
# </style>
#
#     <div class='sb-history-bar'><label for='sb-res-4b746ba82def490e9caec0d8f9eef8e6-history' class='sb-history-label'>History:</label><select id='sb-res-4b746ba82def490e9caec0d8f9eef8e6-history' class='sb-history-select'><option value='0'>Result 1 (exit 0)</option><option value='1'>Result 2 (exit 0)</option></select></div>
#     <div class='sb-history-panel' data-index='0' style='display:none;'><div id='sb-res-4b746ba82def490e9caec0d8f9eef8e6-tabs-0' class='sb-tabs'><div class='sb-tab-buttons'><button class='sb-tab-btn active' type='button' data-tab-index='0'>Output</button><button class='sb-tab-btn' type='button' data-tab-index='1'>Code</button><button class='sb-tab-btn' type='button' data-tab-index='2'>Prompt</button><button class='sb-tab-btn' type='button' data-tab-index='3'>Details</button><button class='sb-tab-btn' type='button' data-tab-index='4'>StdOut</button><button class='sb-tab-btn' type='button' data-tab-index='5'>StdErr</button></div><div class='sb-tab-content'><div class='sb-tab-panel active' data-panel-index='0'><div><h4>Execution Output</h4><pre>Histograms of each column in measurements.csv</pre><p><img src='data:image/png;base64,...'/></p></div></div><div class='sb-tab-panel' data-panel-index='1'><div><h4>Executed Code</h4><pre style='background: white; padding: 10px; border-radius: 5px; overflow-x: auto; font-family: monospace;'># Import required libraries
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import math
#
# # Load the data
# df = pd.read_csv(&#x27;input_data/measurements.csv&#x27;)
#
# # Determine layout for sub‑plots
# n_cols = df.shape[1]
# n_rows = math.ceil(n_cols / 3)           # show up to 3 histograms per row
# fig, axes = plt.subplots(n_rows, 3, figsize=(15, 4 * n_rows))
# axes = axes.flatten()                     # make indexing easier
#
# # Plot a histogram for each column
# for i, col in enumerate(df.columns):
#     ax = axes[i]
#     # Use seaborn for a nice looking histogram
#     sns.histplot(df[col].dropna(), kde=False, bins=30, ax=ax, color=&#x27;steelblue&#x27;)
#     ax.set_title(col)
#     ax.set_xlabel(&#x27;Value&#x27;)
#     ax.set_ylabel(&#x27;Count&#x27;)
#
# # Hide any unused sub‑plots
# for j in range(i + 1, len(axes)):
#     axes[j].set_visible(False)
#
# plt.tight_layout()
#
# # Second‑last output: description of the result
# print(&quot;Histograms of each column in measurements.csv&quot;)
#
# # Last output: display the plot
# plt.show()</pre></div></div><div class='sb-tab-panel' data-panel-index='2'><div><h4>Prompt</h4><pre style='background: white; padding: 10px; border-radius: 5px; overflow-x: auto; font-family: monospace;'>
# You are an expert in python programming. You have a list of framework constraints which you MUST follow.
# Your task is to generate a fully functional code snippet that will be used to fulfill the prompt.
# Assume your code will be executed in a Jupyter notebook cell.
#
# # Framework constraints
# * You may use the following libraries, but only if necessary: scikit-image, numpy, pandas, matplotlib, seaborn, tqdm, scipy
# * pip install is STRICTLY PROHIBITED. You can only use the libraries mentioned above.
# * Statistics: When applying statisticals test, ENSURE that pre-conditions for the tests are checked before the tests are performed.
# * Final result output (print or display calls):
#   * The second-last print or display call should be a description of the result (e.g. the measurment and a physical unit if relevant).
#   * The last print or display call should be the final result ONLY.
#   * If the task is to generate a count, ratio or measurements, print the final result using a separate `print` call.
#   * If the task is to answer a yes/no question, print &quot;Yes&quot; or &quot;No&quot; using a separate `print` call. Do not create any JSON for this.
#   * If the task is to generate a plot, display the plot.
#   * Also plot intermediate results if possible.
# * Final result output (file writing):
#   * If the task is to generate a text or a string, write the text or string to &quot;/display_output/final_result.txt&quot;.
#   * If the task is to generate a table, write the table to &quot;/display_output/final_result.csv&quot;.
#   * If the task is to generate a number, list, array or dictionary, write the result to &quot;/display_output/final_result.json&quot;.
#     In that case, do not add additional data structures. Simply json.dump the result to the file. E.g. if the result is x=2, then just do `json.dump(x, fp)`.
# * Keep the code short and concise.
#
#
# Plot histograms of all columns in input_data/measurements.csv
# </pre></div></div><div class='sb-tab-panel' data-panel-index='3'><div><h4>Execution Details</h4><ul style='list-style: none; padding: 0;'><li><strong>Execution reason:</strong> Initial execution</li><li><strong>Final result:</strong> ...</li><li><strong>Exit Code:</strong> <span style='color: green;'>0</span></li><li><strong>Build Time:</strong> 3.90s</li><li><strong>Run Time:</strong> 7.52s</li><li><strong>Execution Time:</strong> 11.47s</li><li><strong>Container ID:</strong> 92e40193a605726c12c8ef113458aab4001cb7cc5aa89e5f8170075e0b2df01a</li><li><strong>Dependencies:</strong> scikit-image, numpy, pandas, matplotlib, seaborn, tqdm, scipy</li><li><strong>Files:</strong><ul><li>/display_output/notebook_executed.ipynb</li></ul></li><li><strong>Number of attempts:</strong> 1</li><li><strong>Feedback:</strong><pre style='background: #f1f1f1; padding: 10px; border-radius: 5px; color: red;'>### Feedback
#
# **Data Analysis &amp; Sanity Checks**
# The `Unnamed: 0` column is clearly an index/ID column, not a measurement. Including it in the histograms is misleading. It should be dropped or set as the index.
#
# **Final Result**
# The task requires the final plot to be saved to `/display_output` as `.png` and `.svg` files, and the filenames must be printed.
#
# **Code Quality**
# The logic for calculating rows and flattening axes is fine, but using `df.hist()` is a more concise way to achieve this in pandas.
#
# #### Improvements
#
# **1. Remove index column and save output
# Output()
# ExecutionResult(stdout='[jupytext] Reading notebook.mystnb in format mystnb\n[jupytext] Writing notebook.ipynb\n[NbConvertApp] Converting notebook notebook.ipynb to notebook\n[NbConvertApp] Writing 128373 bytes to /display_output/notebook_executed.ipynb\n', stderr='', exit_code=0, execution_time=7.160937070846558, run_time=7.090067386627197, build_time=0.0, container_id='1645d83638f1d31ea1db83c851dc5547dbef8b8c133c992a58aade56516f315c', prompt='\nYou are an expert in python programming. You have a list of framework constraints which you MUST follow.\nYour task is to generate a fully functional code snippet that will be used to fulfill the prompt.\nAssume your code will be executed in a Jupyter notebook cell.\n\n# Framework constraints\n* You may use the following libraries, but only if necessary: scikit-image, numpy, pandas, matplotlib, seaborn, tqdm, scipy\n* pip install is STRICTLY PROHIBITED. You can only use the libraries mentioned above.\n* Statistics: When applying statisticals test, ENSURE that pre-conditions for the tests are checked before the tests are performed.\n* Final result output (print or display calls): \n  * The second-last print or display call should be a description of the result (e.g. the measurment and a physical unit if relevant).\n  * The last print or display call should be the final result ONLY.\n  * If the task is to generate a count, ratio or measurements, print the final result using a separate `print` call. \n  * If the task is to answer a yes/no question, print "Yes" or "No" using a separate `print` call. Do not create any JSON for this.\n  * If the task is to generate a plot, display the plot.\n  * Also plot intermediate results if possible.\n* Final result output (file writing):\n  * If the task is to generate a text or a string, write the text or string to "/display_output/final_result.txt".\n  * If the task is to generate a table, write the table to "/display_output/final_result.csv".\n  * If the task is to generate a number, list, array or dictionary, write the result to "/display_output/final_result.json".\n    In that case, do not add additional data structures. Simply json.dump the result to the file. E.g. if the result is x=2, then just do `json.dump(x, fp)`.\n* Keep the code short and concise.\n\n\n\nGiven some task, code to fulfill the task, and detailed feedback, propose new code that incorporates the feedback.\nMake sure to keep the code format.\n\n# Task\n                \nPlot histograms of all columns in input_data/measurements.csv\n\n                \n# Code\n\n```\n# Import required libraries\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport math\n\n# Load the data\ndf = pd.read_csv(\'input_data/measurements.csv\')\n\n# Determine layout for sub‑plots\nn_cols = df.shape[1]\nn_rows = math.ceil(n_cols / 3)           # show up to 3 histograms per row\nfig, axes = plt.subplots(n_rows, 3, figsize=(15, 4 * n_rows))\naxes = axes.flatten()                     # make indexing easier\n\n# Plot a histogram for each column\nfor i, col in enumerate(df.columns):\n    ax = axes[i]\n    # Use seaborn for a nice looking histogram\n    sns.histplot(df[col].dropna(), kde=False, bins=30, ax=ax, color=\'steelblue\')\n    ax.set_title(col)\n    ax.set_xlabel(\'Value\')\n    ax.set_ylabel(\'Count\')\n\n# Hide any unused sub‑plots\nfor j in range(i + 1, len(axes)):\n    axes[j].set_visible(False)\n\nplt.tight_layout()\n\n# Second‑last output: description of the result\nprint("Histograms of each column in measurements.csv")\n\n# Last output: display the plot\nplt.show()\n```\n\n# Feedback\n\n### Feedback\n\n**Data Analysis & Sanity Checks**\nThe `Unnamed: 0` column is clearly an index/ID column, not a measurement. Including it in the histograms is misleading. It should be dropped or set as the index.\n\n**Final Result**\nThe task requires the final plot to be saved to `/display_output` as `.png` and `.svg` files, and the filenames must be printed.\n\n**Code Quality**\ ...
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]]], dtype=uint8), 'pil_image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1489x1590 at 0x19FCDF06010>}], feedback=None, final_result='...', total_time=50.76407027244568, former_result=ExecutionResult(stdout='[jupytext] Reading notebook.mystnb in format mystnb\n[jupytext] Writing notebook.ipynb\n[NbConvertApp] Converting notebook notebook.ipynb to notebook\n[NbConvertApp] Writing 141373 bytes to /display_output/notebook_executed.ipynb\n', stderr='', exit_code=0, execution_time=11.473149299621582, run_time=7.515680313110352, build_time=3.9039697647094727, container_id='92e40193a605726c12c8ef113458aab4001cb7cc5aa89e5f8170075e0b2df01a', prompt='\nYou are an expert in python programming. You have a list of framework constraints which you MUST follow.\nYour task is to generate a fully functional code snippet that will be used to fulfill the prompt.\nAssume your code will be executed in a Jupyter notebook cell.\n\n# Framework constraints\n* You may use the following libraries, but only if necessary: scikit-image, numpy, pandas, matplotlib, seaborn, tqdm, scipy\n* pip install is STRICTLY PROHIBITED. You can only use the libraries mentioned above.\n* Statistics: When applying statisticals test, ENSURE that pre-conditions for the tests are checked before the tests are performed.\n* Final result output (print or display calls): \n  * The second-last print or display call should be a description of the result (e.g. the measurment and a physical unit if relevant).\n  * The last print or display call should be the final result ONLY.\n  * If the task is to generate a count, ratio or measurements, print the final result using a separate `print` call. \n  * If the task is to answer a yes/no question, print "Yes" or "No" using a separate `print` call. Do not create any JSON for this.\n  * If the task is to generate a plot, display the plot.\n  * Also plot intermediate results if possible.\n* Final result output (file writing):\n  * If the task is to generate a text or a string, write the text or string to "/display_output/final_result.txt".\n  * If the task is to generate a table, write the table to "/display_output/final_result.csv".\n  * If the task is to generate a number, list, array or dictionary, write the result to "/display_output/final_result.json".\n    In that case, do not add additional data structures. Simply json.dump the result to the file. E.g. if the result is x=2, then just do `json.dump(x, fp)`.\n* Keep the code short and concise.\n\n\nPlot histograms of all columns in input_data/measurements.csv\n', code='# Import required libraries\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport math\n\n# Load the data\ndf = pd.read_csv(\'input_data/measurements.csv\')\n\n# Determine layout for sub‑plots\nn_cols = df.shape[1]\nn_rows = math.ceil(n_cols / 3)           # show up to 3 histograms per row\nfig, axes = plt.subplots(n_rows, 3, figsize=(15, 4 * n_rows))\naxes = axes.flatten()                     # make indexing easier\n\n# Plot a histogram for each column\nfor i, col in enumerate(df.columns):\n    ax = axes[i]\n    # Use seaborn for a nice looking histogram\n    sns.histplot(df[col].dropna(), kde=False, bins=30, ax=ax, color=\'steelblue\')\n    ax.set_title(col)\n    ax.set_xlabel(\'Value\')\n    ax.set_ylabel(\'Count\')\n\n# Hide any unused sub‑plots\nfor j in range(i + 1, len(axes)):\n    axes[j].set_visible(False)\n\nplt.tight_layout()\n\n# Second‑last output: description of the result\nprint("Histograms of each column in measurements.csv")\n\n# Last output: display the plot\nplt.show()', dependencies=['scikit-image', 'numpy', 'pandas', 'matplotlib', 'seaborn', 'tqdm', 'scipy'], traceback=None, files={'/display_output/notebook_executed.ipynb': b'{\n "cells": [\n  {\n   "cell_type": "code",\n   "execution_count": 1,\n   "id": "4596a60e",\n   "metadata": {\n    "execution": {\n     "iopub.execute_input": "2026-05-23T12:35:58.232621Z",\n     "iopub.status.b ...
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]]], dtype=uint8), 'pil_image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1488x1990 at 0x19FA66FF2D0>}], feedback="### Feedback\n\n**Data Analysis & Sanity Checks**\nThe `Unnamed: 0` column is clearly an index/ID column, not a measurement. Including it in the histograms is misleading. It should be dropped or set as the index.\n\n**Final Result**\nThe task requires the final plot to be saved to `/display_output` as `.png` and `.svg` files, and the filenames must be printed.\n\n**Code Quality**\nThe logic for calculating rows and flattening axes is fine, but using `df.hist()` is a more concise way to achieve this in pandas.\n\n#### Improvements\n\n**1. Remove index column and save output**\n\nOld code:\n```python\n# Load the data\ndf = pd.read_csv('input_data/measurements.csv')\n\n# ... (plotting code) ...\n\n# Last output: display the plot\nplt.show()\n```\n\nNew code:\n```python\nimport os\n\n# Load data and remove the index column (Unnamed: 0)\ndf = pd.read_csv('input_data/measurements.csv', index_col=0)\n\n# ... (plotting code) ...\n\nplt.tight_layout()\n\n# Save results to /display_output\nos.makedirs('/display_output', exist_ok=True)\nplt.savefig('/display_output/histograms.png')\nplt.savefig('/display_output/histograms.svg')\n\nplt.show()\nprint('/display_output/histograms.png')\nprint('/display_output/histograms.svg')\n```\n\n**2. Simplified Plotting (Optional but preferred)**\nInstead of manually calculating grids and loops, use the built-in pandas wrapper.\n\nOld code:\n```python\nn_cols = df.shape[1]\nn_rows = math.ceil(n_cols / 3)\nfig, axes = plt.subplots(n_rows, 3, figsize=(15, 4 * n_rows))\naxes = axes.flatten()\n\nfor i, col in enumerate(df.columns):\n    ax = axes[i]\n    sns.histplot(df[col].dropna(), kde=False, bins=30, ax=ax, color='steelblue')\n    # ... labels ...\n```\n\nNew code:\n```python\n# Pandas .hist() handles the grid and titles automatically\ndf.hist(bins=30, figsize=(15, 4 * math.ceil(df.shape[1]/3)), color='steelblue', edgecolor='white')\nplt.tight_layout()\n```", final_result='...', total_time=None, former_result=None, render_inline=False, build_log=["{'stream': 'Step 1/6 : FROM python:3.11-slim'}", "{'stream': '\\n'}", "{'stream': ' ---> 5e9093a415c6\\n'}", "{'stream': 'Step 2/6 : WORKDIR /app'}", "{'stream': '\\n'}", "{'stream': ' ---> Using cache\\n'}", "{'stream': ' ---> ef90e4b579b6\\n'}", "{'stream': 'Step 3/6 : RUN apt-get update && apt-get install -y     gcc     && rm -rf /var/lib/apt/lists/*'}", "{'stream': '\\n'}", "{'stream': ' ---> Using cache\\n'}", "{'stream': ' ---> d451efe4487c\\n'}", "{'stream': 'Step 4/6 : RUN pip install --no-cache-dir jupyter nbconvert jupytext'}", "{'stream': '\\n'}", "{'stream': ' ---> Using cache\\n'}", "{'stream': ' ---> 8633d6ac8f3a\\n'}", "{'stream': 'Step 5/6 : COPY requirements.txt .'}", "{'stream': '\\n'}", "{'stream': ' ---> Using cache\\n'}", "{'stream': ' ---> 3fdf6cb05aa3\\n'}", "{'stream': 'Step 6/6 : RUN pip install --no-cache-dir -r requirements.txt'}", "{'stream': '\\n'}", "{'stream': ' ---> Using cache\\n'}", "{'stream': ' ---> eca091445dd3\\n'}", "{'aux': {'ID': 'sha256:eca091445dd317ee4a05fcb9ee30038b07337ac6750491c26de7640f34fce2f5'}}", "{'stream': 'Successfully built eca091445dd3\\n'}", "{'stream': 'Successfully tagged sand-bob-3430f6d1bf85b7c375c6f5a460e052a1:latest\\n'}"], summary=None, error=None, reason='Initial execution'), render_inline=False, build_log=None, summary=None, error=None, reason='Exe')

# %%
# %%alice
# Visualize a coloured correlation matrix of all columns in input_data/measurements.csv
# Out:
# <div id='sb-res-d7ce29d35dac43dc82dbd5150ee78feb' class='sb-result-root'>
#
# <style>
# .sb-result-root {
#     --sb-border: #cfcfcf;
#     --sb-tab-bg: #f2f2f2;
#     --sb-tab-hover-bg: #ebebeb;
#     --sb-active-bg: #ffffff;
#     --sb-content-bg: #ffffff;
#     --sb-text: #2f2f2f;
#     --sb-shadow: rgba(0, 0, 0, 0.04);
#     margin-top: 8px;
#     color: var(--sb-text);
# }
#
# .sb-history-bar {
#     margin: 0 0 10px 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
# }
#
# .sb-history-label {
#     font-weight: 600;
#     font-size: 13px;
# }
#
# .sb-history-select {
#     min-width: 210px;
#     padding: 4px 8px;
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: #fff;
#     color: var(--sb-text);
# }
#
# .sb-history-panel {
#     margin: 0;
# }
#
# .sb-tabs {
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: var(--sb-content-bg);
#     box-shadow: inset 0 1px 0 var(--sb-shadow);
# }
#
# .sb-tab-buttons {
#     display: flex;
#     align-items: flex-end;
#     gap: 0;
#     border-bottom: 1px solid var(--sb-border);
#     background: linear-gradient(to bottom, #f8f8f8 0%, #f1f1f1 100%);
#     overflow-x: auto;
#     scrollbar-width: thin;
# }
#
# .sb-tab-btn {
#     appearance: none;
#     border: 0;
#     border-right: 1px solid #dddddd;
#     border-bottom: 1px solid var(--sb-border);
#     margin: 0;
#     background: var(--sb-tab-bg);
#     color: var(--sb-text);
#     padding: 7px 12px;
#     cursor: pointer;
#     font-size: 13px;
#     line-height: 1.25;
#     white-space: nowrap;
#     position: relative;
# }
#
# .sb-tab-btn:hover {
#     background: var(--sb-tab-hover-bg);
# }
#
# .sb-tab-btn.active {
#     background: var(--sb-active-bg);
#     font-weight: 600;
#     border-bottom: 1px solid var(--sb-active-bg);
#     box-shadow: inset 0 2px 0 #e6e6e6;
#     z-index: 1;
# }
#
# .sb-tab-content {
#     padding: 12px;
#     background: var(--sb-content-bg);
# }
#
# .sb-tab-panel {
#     display: none;
# }
#
# .sb-tab-panel.active {
#     display: block;
# }
#
# .sb-tab-content pre {
#     margin-top: 6px;
#     border: 1px solid #ececec;
# }
# </style>
#
#     <div class='sb-history-bar'><label for='sb-res-d7ce29d35dac43dc82dbd5150ee78feb-history' class='sb-history-label'>History:</label><select id='sb-res-d7ce29d35dac43dc82dbd5150ee78feb-history' class='sb-history-select'><option value='0'>Result 1 (exit 0)</option><option value='1'>Result 2 (exit 0)</option></select></div>
#     <div class='sb-history-panel' data-index='0' style='display:none;'><div id='sb-res-d7ce29d35dac43dc82dbd5150ee78feb-tabs-0' class='sb-tabs'><div class='sb-tab-buttons'><button class='sb-tab-btn active' type='button' data-tab-index='0'>Output</button><button class='sb-tab-btn' type='button' data-tab-index='1'>Code</button><button class='sb-tab-btn' type='button' data-tab-index='2'>Prompt</button><button class='sb-tab-btn' type='button' data-tab-index='3'>Details</button><button class='sb-tab-btn' type='button' data-tab-index='4'>StdOut</button><button class='sb-tab-btn' type='button' data-tab-index='5'>StdErr</button></div><div class='sb-tab-content'><div class='sb-tab-panel active' data-panel-index='0'><div><h4>Execution Output</h4><pre>Displayed a coloured correlation matrix heatmap of all numeric columns.</pre><p><img src='data:image/png;base64,...'/></p></div></div><div class='sb-tab-panel' data-panel-index='1'><div><h4>Executed Code</h4><pre style='background: white; padding: 10px; border-radius: 5px; overflow-x: auto; font-family: monospace;'>import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Load the data
# df = pd.read_csv(&quot;input_data/measurements.csv&quot;)
#
# # Keep only numeric columns for correlation
# numeric_df = df.select_dtypes(include=&quot;number&quot;)
#
# # Compute the correlation matrix
# corr_matrix = numeric_df.corr()
#
# # Plot the correlation matrix as a coloured heatmap
# plt.figure(figsize=(10, 8))
# sns.heatmap(
#     corr_matrix,
#     annot=True,
#     fmt=&quot;.2f&quot;,
#     cmap=&quot;coolwarm&quot;,
#     linewidths=0.5,
#     cbar_kws={&quot;label&quot;: &quot;Correlation coefficient&quot;},
#     square=True,
# )
# plt.title(&quot;Correlation Matrix of Measurements&quot;)
# plt.xticks(rotation=45, ha=&quot;right&quot;)
# plt.yticks(rotation=0)
#
# # Second‑last output: description of the result
# print(&quot;Displayed a coloured correlation matrix heatmap of all numeric columns.&quot;)
#
# # Final output: the plot itself
# plt.show()</pre></div></div><div class='sb-tab-panel' data-panel-index='2'><div><h4>Prompt</h4><pre style='background: white; padding: 10px; border-radius: 5px; overflow-x: auto; font-family: monospace;'>
# You are an expert in python programming. You have a list of framework constraints which you MUST follow.
# Your task is to generate a fully functional code snippet that will be used to fulfill the prompt.
# Assume your code will be executed in a Jupyter notebook cell.
#
# # Framework constraints
# * You may use the following libraries, but only if necessary: scikit-image, numpy, pandas, matplotlib, seaborn, tqdm, scipy
# * pip install is STRICTLY PROHIBITED. You can only use the libraries mentioned above.
# * Statistics: When applying statisticals test, ENSURE that pre-conditions for the tests are checked before the tests are performed.
# * Final result output (print or display calls):
#   * The second-last print or display call should be a description of the result (e.g. the measurment and a physical unit if relevant).
#   * The last print or display call should be the final result ONLY.
#   * If the task is to generate a count, ratio or measurements, print the final result using a separate `print` call.
#   * If the task is to answer a yes/no question, print &quot;Yes&quot; or &quot;No&quot; using a separate `print` call. Do not create any JSON for this.
#   * If the task is to generate a plot, display the plot.
#   * Also plot intermediate results if possible.
# * Final result output (file writing):
#   * If the task is to generate a text or a string, write the text or string to &quot;/display_output/final_result.txt&quot;.
#   * If the task is to generate a table, write the table to &quot;/display_output/final_result.csv&quot;.
#   * If the task is to generate a number, list, array or dictionary, write the result to &quot;/display_output/final_result.json&quot;.
#     In that case, do not add additional data structures. Simply json.dump the result to the file. E.g. if the result is x=2, then just do `json.dump(x, fp)`.
# * Keep the code short and concise.
#
#
# Visualize a coloured correlation matrix of all columns in input_data/measurements.csv
# </pre></div></div><div class='sb-tab-panel' data-panel-index='3'><div><h4>Execution Details</h4><ul style='list-style: none; padding: 0;'><li><strong>Execution reason:</strong> Initial execution</li><li><strong>Final result:</strong> ...</li><li><strong>Exit Code:</strong> <span style='color: green;'>0</span></li><li><strong>Build Time:</strong> 0.00s</li><li><strong>Run Time:</strong> 6.72s</li><li><strong>Execution Time:</strong> 6.79s</li><li><strong>Container ID:</strong> 69b7e7b57f28c8bde3d610c578f1e6ff040d6f9f87f5899180adfdd5127cd5b8</li><li><strong>Dependencies:</strong> scikit-image, numpy, pandas, matplotlib, seaborn, tqdm, scipy</li><li><strong>Files:</strong><ul><li>/display_output/notebook_executed.ipynb</li></ul></li><li><strong>Number of attempts:</strong> 1</li><li><strong>Feedback:</strong><pre style='background: #f1f1f1; padding: 10px; border-radius: 5px; color: red;'>### Feedback
#
# **Data Analysis &amp; Sanity Checks**
# The correlation matrix includes columns like `Unnamed: 0` and `bbox-0` through `bbox-3`. These are typically index columns or coordinate metadata, not actual measurements. Including them in a correlation analysis is misleading and creates noise. These should be filtered out.
#
# **Final Result Handling**
# According to the requirements, plots must be saved to `/display_output` as `.png` and `.svg` files, and the filenames must be printed.
#
# **Code Improvements**
#
# Old code:
# ```python
# # Keep only numeric columns for correlation
# numeric_df = df.select_dtypes(include=&quot;number&quot;)
#
# # Co
# Output()
# ExecutionResult(stdout='[jupytext] Reading notebook.mystnb in format mystnb\n[jupytext] Writing notebook.ipynb\n[NbConvertApp] Converting notebook notebook.ipynb to notebook\n[NbConvertApp] Writing 135010 bytes to /display_output/notebook_executed.ipynb\n', stderr='', exit_code=0, execution_time=7.658123016357422, run_time=7.58673357963562, build_time=0.0, container_id='6940cd35f62dd7176eb3bbe261af8b3f2698ba98aba7fa0b2fbfe0bcefa2f33d', prompt='\nYou are an expert in python programming. You have a list of framework constraints which you MUST follow.\nYour task is to generate a fully functional code snippet that will be used to fulfill the prompt.\nAssume your code will be executed in a Jupyter notebook cell.\n\n# Framework constraints\n* You may use the following libraries, but only if necessary: scikit-image, numpy, pandas, matplotlib, seaborn, tqdm, scipy\n* pip install is STRICTLY PROHIBITED. You can only use the libraries mentioned above.\n* Statistics: When applying statisticals test, ENSURE that pre-conditions for the tests are checked before the tests are performed.\n* Final result output (print or display calls): \n  * The second-last print or display call should be a description of the result (e.g. the measurment and a physical unit if relevant).\n  * The last print or display call should be the final result ONLY.\n  * If the task is to generate a count, ratio or measurements, print the final result using a separate `print` call. \n  * If the task is to answer a yes/no question, print "Yes" or "No" using a separate `print` call. Do not create any JSON for this.\n  * If the task is to generate a plot, display the plot.\n  * Also plot intermediate results if possible.\n* Final result output (file writing):\n  * If the task is to generate a text or a string, write the text or string to "/display_output/final_result.txt".\n  * If the task is to generate a table, write the table to "/display_output/final_result.csv".\n  * If the task is to generate a number, list, array or dictionary, write the result to "/display_output/final_result.json".\n    In that case, do not add additional data structures. Simply json.dump the result to the file. E.g. if the result is x=2, then just do `json.dump(x, fp)`.\n* Keep the code short and concise.\n\n\n\nGiven some task, code to fulfill the task, and detailed feedback, propose new code that incorporates the feedback.\nMake sure to keep the code format.\n\n# Task\n                \nVisualize a coloured correlation matrix of all columns in input_data/measurements.csv\n\n                \n# Code\n\n```\nimport pandas as pd\nimport seaborn as sns\nimport matplotlib.pyplot as plt\n\n# Load the data\ndf = pd.read_csv("input_data/measurements.csv")\n\n# Keep only numeric columns for correlation\nnumeric_df = df.select_dtypes(include="number")\n\n# Compute the correlation matrix\ncorr_matrix = numeric_df.corr()\n\n# Plot the correlation matrix as a coloured heatmap\nplt.figure(figsize=(10, 8))\nsns.heatmap(\n    corr_matrix,\n    annot=True,\n    fmt=".2f",\n    cmap="coolwarm",\n    linewidths=0.5,\n    cbar_kws={"label": "Correlation coefficient"},\n    square=True,\n)\nplt.title("Correlation Matrix of Measurements")\nplt.xticks(rotation=45, ha="right")\nplt.yticks(rotation=0)\n\n# Second‑last output: description of the result\nprint("Displayed a coloured correlation matrix heatmap of all numeric columns.")\n\n# Final output: the plot itself\nplt.show()\n```\n\n# Feedback\n\n### Feedback\n\n**Data Analysis & Sanity Checks**\nThe correlation matrix includes columns like `Unnamed: 0` and `bbox-0` through `bbox-3`. These are typically index columns or coordinate metadata, not actual measurements. Including them in a correlation analysis is misleading and creates noise. These should be filtered out.\n\n**Final Result Handling**\nAccording to the requirements, plots must be saved to `/display_output` as `.png` and `.svg` files, and the filenames must be printed.\n\n**Code Improvements**\n\nOld code:\ ...
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]]], dtype=uint8), 'pil_image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=959x806 at 0x19FD4CFF510>}, {'type': 'text/plain', 'data': "Displayed a coloured correlation matrix heatmap of measurement columns.\n['/display_output/correlation_matrix.png', '/display_output/correlation_matrix.svg']"}], feedback=None, final_result="['/display_output/correlation_matrix.png', '/display_output/correlation_matrix.svg']", total_time=37.862770080566406, former_result=ExecutionResult(stdout='[jupytext] Reading notebook.mystnb in format mystnb\n[jupytext] Writing notebook.ipynb\n[NbConvertApp] Converting notebook notebook.ipynb to notebook\n[NbConvertApp] Writing 225531 bytes to /display_output/notebook_executed.ipynb\n', stderr='', exit_code=0, execution_time=6.78584885597229, run_time=6.716800928115845, build_time=0.0, container_id='69b7e7b57f28c8bde3d610c578f1e6ff040d6f9f87f5899180adfdd5127cd5b8', prompt='\nYou are an expert in python programming. You have a list of framework constraints which you MUST follow.\nYour task is to generate a fully functional code snippet that will be used to fulfill the prompt.\nAssume your code will be executed in a Jupyter notebook cell.\n\n# Framework constraints\n* You may use the following libraries, but only if necessary: scikit-image, numpy, pandas, matplotlib, seaborn, tqdm, scipy\n* pip install is STRICTLY PROHIBITED. You can only use the libraries mentioned above.\n* Statistics: When applying statisticals test, ENSURE that pre-conditions for the tests are checked before the tests are performed.\n* Final result output (print or display calls): \n  * The second-last print or display call should be a description of the result (e.g. the measurment and a physical unit if relevant).\n  * The last print or display call should be the final result ONLY.\n  * If the task is to generate a count, ratio or measurements, print the final result using a separate `print` call. \n  * If the task is to answer a yes/no question, print "Yes" or "No" using a separate `print` call. Do not create any JSON for this.\n  * If the task is to generate a plot, display the plot.\n  * Also plot intermediate results if possible.\n* Final result output (file writing):\n  * If the task is to generate a text or a string, write the text or string to "/display_output/final_result.txt".\n  * If the task is to generate a table, write the table to "/display_output/final_result.csv".\n  * If the task is to generate a number, list, array or dictionary, write the result to "/display_output/final_result.json".\n    In that case, do not add additional data structures. Simply json.dump the result to the file. E.g. if the result is x=2, then just do `json.dump(x, fp)`.\n* Keep the code short and concise.\n\n\nVisualize a coloured correlation matrix of all columns in input_data/measurements.csv\n', code='import pandas as pd\nimport seaborn as sns\nimport matplotlib.pyplot as plt\n\n# Load the data\ndf = pd.read_csv("input_data/measurements.csv")\n\n# Keep only numeric columns for correlation\nnumeric_df = df.select_dtypes(include="number")\n\n# Compute the correlation matrix\ncorr_matrix = numeric_df.corr()\n\n# Plot the correlation matrix as a coloured heatmap\nplt.figure(figsize=(10, 8))\nsns.heatmap(\n    corr_matrix,\n    annot=True,\n    fmt=".2f",\n    cmap="coolwarm",\n    linewidths=0.5,\n    cbar_kws={"label": "Correlation coefficient"},\n    square=True,\n)\nplt.title("Correlation Matrix of Measurements")\nplt.xticks(rotation=45, ha="right")\nplt.yticks(rotation=0)\n\n# Second‑last output: description of the result\nprint("Displayed a coloured correlation matrix heatmap of all numeric columns.")\n\n# Final output: the plot itself\nplt.show()', dependencies=['scikit-image', 'numpy', 'pandas', 'matplotlib', 'seaborn', 'tqdm', 'scipy'], traceback=None, files={'/display_output/notebook_executed.ipynb': b'{\n "cells": [\n  {\n   "cell_type": "code",\n   "execution_count": 1,\n   "id": "06557e77",\n   "meta ...
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]]], dtype=uint8), 'pil_image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=959x806 at 0x19FD4CCAED0>}], feedback='### Feedback\n\n**Data Analysis & Sanity Checks**\nThe correlation matrix includes columns like `Unnamed: 0` and `bbox-0` through `bbox-3`. These are typically index columns or coordinate metadata, not actual measurements. Including them in a correlation analysis is misleading and creates noise. These should be filtered out.\n\n**Final Result Handling**\nAccording to the requirements, plots must be saved to `/display_output` as `.png` and `.svg` files, and the filenames must be printed.\n\n**Code Improvements**\n\nOld code:\n```python\n# Keep only numeric columns for correlation\nnumeric_df = df.select_dtypes(include="number")\n\n# Compute the correlation matrix\ncorr_matrix = numeric_df.corr()\n\n# ... plotting ...\nplt.show()\n```\n\nNew code:\n```python\n# Keep only numeric columns and drop metadata/index columns\ncols_to_drop = [c for c in df.columns if \'Unnamed\' in c or \'bbox\' in c]\nnumeric_df = df.select_dtypes(include="number").drop(columns=cols_to_drop)\n\n# Compute the correlation matrix\ncorr_matrix = numeric_df.corr()\n\n# ... plotting ...\nplt.title("Correlation Matrix of Measurements")\nplt.xticks(rotation=45, ha="right")\nplt.yticks(rotation=0)\n\n# Save and display as per requirements\nplt.savefig("/display_output/correlation_matrix.png")\nplt.savefig("/display_output/correlation_matrix.svg")\nplt.show()\nprint("/display_output/correlation_matrix.png")\nprint("/display_output/correlation_matrix.svg")\n```\n\n**Modifications:**\n1. **Feature Selection:** Added a filter to remove `Unnamed` and `bbox` columns to ensure only actual measurements are analyzed.\n2. **Output Compliance:** Added logic to save the plot in the required directory and formats, printing the filenames as the final output.', final_result='...', total_time=None, former_result=None, render_inline=False, build_log=None, summary=None, error=None, reason='Initial execution'), render_inline=False, build_log=None, summary=None, error=None, reason='Exe')

# %% [markdown]
# By initializing multiple parallel attempts, you can also run analysis in parallel and inspect results interactively.

# %%
initialize(n_parallel=5)

# %%
# %%alice
# how many b are in blueberry?
# Out:
#         <div style="font-family: Arial, sans-serif; padding: 0px;">
#
#         <div style="position: relative; width: 100%; height: 20px; background-color: #f5f5f5; border-radius: 1px; margin: 0px 0px; overflow: hidden;">
#
#             <div style="position: absolute; top: 0; left: 0; width: 40.0%; height: 100%; background-color: #2EB870; transition: width 0.3s ease;"></div>
#             <div style="position: absolute; top: 0; left: 0; width: 40.0%; height: 100%; display: flex; align-items: left; justify-content: left; z-index: 3;">
#                 <span style="color: #ffffff; font-size: 12px;">Process 2/5 completed</span>
#             </div>
#
#             <div style="position: absolute; top: 0; left: 0; width: 100%; height: 100%; display: flex; align-items: left; justify-content: left; z-index: 1;">
#                 <span style="color: #000000; font-size: 12px; position: relative; z-index: 2;">Process 2/5 completed</span>
#             </div>
#         </div>
#
#         </div>
#         <div style="font-family: Arial, sans-serif; padding: 0px;">
#
#         <div style="position: relative; width: 100%; height: 20px; background-color: #f5f5f5; border-radius: 1px; margin: 0px 0px; overflow: hidden;">
#
#             <div style="position: absolute; top: 0; left: 0; width: 62.5%; height: 100%; background-color: #3874CC; transition: width 0.3s ease;"></div>
#             <div style="position: absolute; top: 0; left: 0; width: 62.5%; height: 100%; display: flex; align-items: left; justify-content: left; z-index: 3;">
#                 <span style="color: #ffffff; font-size: 12px;">Executing code...</span>
#             </div>
#
#             <div style="position: absolute; top: 0; left: 0; width: 100%; height: 100%; display: flex; align-items: left; justify-content: left; z-index: 1;">
#                 <span style="color: #000000; font-size: 12px; position: relative; z-index: 2;">Executing code...</span>
#             </div>
#         </div>
#
#         </div>
#         <div style="font-family: Arial, sans-serif; padding: 0px;">
#
#         <div style="position: relative; width: 100%; height: 20px; background-color: #f5f5f5; border-radius: 1px; margin: 0px 0px; overflow: hidden;">
#
#             <div style="position: absolute; top: 0; left: 0; width: 62.5%; height: 100%; background-color: #3874CC; transition: width 0.3s ease;"></div>
#             <div style="position: absolute; top: 0; left: 0; width: 62.5%; height: 100%; display: flex; align-items: left; justify-content: left; z-index: 3;">
#                 <span style="color: #ffffff; font-size: 12px;">Executing code...</span>
#             </div>
#
#             <div style="position: absolute; top: 0; left: 0; width: 100%; height: 100%; display: flex; align-items: left; justify-content: left; z-index: 1;">
#                 <span style="color: #000000; font-size: 12px; position: relative; z-index: 2;">Executing code...</span>
#             </div>
#         </div>
#
#         </div>
#         <div style="font-family: Arial, sans-serif; padding: 0px;">
#
#         <div style="position: relative; width: 100%; height: 20px; background-color: #f5f5f5; border-radius: 1px; margin: 0px 0px; overflow: hidden;">
#
#             <div style="position: absolute; top: 0; left: 0; width: 62.5%; height: 100%; background-color: #3874CC; transition: width 0.3s ease;"></div>
#             <div style="position: absolute; top: 0; left: 0; width: 62.5%; height: 100%; display: flex; align-items: left; justify-content: left; z-index: 3;">
#                 <span style="color: #ffffff; font-size: 12px;">Executing code...</span>
#             </div>
#
#             <div style="position: absolute; top: 0; left: 0; width: 100%; height: 100%; display: flex; align-items: left; justify-content: left; z-index: 1;">
#                 <span style="color: #000000; font-size: 12px; position: relative; z-index: 2;">Executing code...</span>
#             </div>
#         </div>
#
#         </div>
