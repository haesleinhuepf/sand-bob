# %%
from sand_bob import initialize, config_kisski
config_kisski()
initialize(input_host_path="input_data/", n_parallel=5)

# %%
# %%alice
# There is an image input_data/timelapse.tif with two channels: nucleus and nuclear envelope.
# Segment the nucleus using Gaussian blur and Otsu's method and measure intensity on its outer pixels.
# The dataset is a timelapse dataet. Hence, we need to measure timepoint by timepoint.
# The final result should be a vector of intensities over time with 14 measurements.
# Out:
# C:\structure\code\sand-bob\sand_bob\_executor.py:652: UserWarning: Error reading JSON file /display_output/final_result.json: Expecting value: line 1 column 2 (char 1)
#
#  b'['
#   warnings.warn(f"Error reading JSON file {filename}: {e} \n\n {str(content)}")
# Tab(children=(Tab(children=(Output(), Output(), Output(), Output(), Output(), Output()), layout=Layout(height=…
