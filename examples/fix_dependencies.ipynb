# %%
from sand_bob._code_gen import run_auto_fix

# %%
run_auto_fix("""
import pandas as pd
import seaborn as sns
                 
pd.DataFrame({"A":[1,2,3], "B":[4,5,6]})
                 
sns.scatterplot(x="A", y="B", data=df)
""")
# Out:
# Response (json dependencies): ["pandas"]
# Executing again with new dependencies: ['pandas']
# Response (json dependencies): ["seaborn", "matplotlib"]
# Executing again with new dependencies: ['seaborn', 'matplotlib']
# Response (code): import pandas as pd
# import seaborn as sns
#
# df = pd.DataFrame({"A":[1,2,3], "B":[4,5,6]})
#
# sns.scatterplot(x="A", y="B", data=df)
# Executing again with new code: import pandas as pd
# import seaborn as sns
#
# df = pd.DataFrame({"A":[1,2,3], "B":[4,5,6]})
#
# sns.scatterplot(x="A", y="B", data=df)
# New dependency list: ['pandas', 'seaborn', 'matplotlib']
# (ExecutionResult(stdout='Traceback (most recent call last):\n  File "/app/code.py", line 7, in <module>\n    sns.scatterplot(x="A", y="B", data=df)\n                                       ^^\nNameError: name \'df\' is not defined\n', stderr='', exit_code=0, execution_time=35.779521465301514, container_id='29c49f2c43e4949aa3141e449e68c36235133b71c87447bc18b704f3313f4eab'),
#  ['pandas', 'seaborn', 'matplotlib'])

# %%
run_auto_fix("""
import pandas as pd
import seaborn as sns
                 
df =pd.DataFrame({"A":[1,2,3], "B":[4,5,6]})
                 
sns.scatterplot(x="A", y="B", data=df)
""")
# Out:
# (ExecutionResult(stdout='', stderr='', exit_code=0, execution_time=10.031195878982544, container_id='9379f3e1318a6246a9ba12e415ebce54d32fb9a0475f94198c8e7fa6b8e1346a'),
#  ['pandas', 'seaborn', 'matplotlib'])
