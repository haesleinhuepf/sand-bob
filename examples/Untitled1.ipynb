# %%
from sand_bob._code_gen import generate_run_check

# %%
_, code, res = generate_run_check("Plot a sigmoid")

code
# Out:
# Response (json dependencies): ["numpy", "matplotlib"]
# Executing again with new dependencies: ['numpy', 'matplotlib']
# New dependency list: ['numpy', 'matplotlib']
# 'import numpy as np\nimport matplotlib.pyplot as plt\n\n# Define the sigmoid function\ndef sigmoid(x):\n    return 1 / (1 + np.exp(-x))\n\n# Generate x values\nx = np.linspace(-10, 10, 100)\n\n# Calculate corresponding y values\ny = sigmoid(x)\n\n# Display the intermediate result\nprint("Sigmoid values calculated.")\n\n# Create the plot\nplt.plot(x, y)\nplt.title("Sigmoid Function")\nplt.xlabel("x")\nplt.ylabel("sigmoid(x)")\nplt.grid(True)\n\n# Display the plot\nprint("Plotting the sigmoid function.")\nplt.show()'

# %%
from skimage.io import imread
from io import BytesIO
import stackview

byte_list = list(res.files.values())[0]  # Replace with your actual list of bytes
img = imread(BytesIO(bytes(byte_list)))
stackview.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 from io import BytesIO
#       3 import stackview
# ----> 5 byte_list = list(res.files.values())[0]  # Replace with your actual list of bytes
#       6 img = imread(BytesIO(bytes(byte_list)))
#       7 stackview.imshow(img)
#
# IndexError: list index out of range
