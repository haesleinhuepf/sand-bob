# %%
from sand_bob import execute
import os 

# Execute code with dependencies
code = """
import numpy as np
import pandas as pd
print("hello world", np.__version__)


mounted_dir = "/mounted_data/"

df = pd.read_csv(mounted_dir + "test.csv")

co = df.corr()

co.to_csv(mounted_dir + "test_corr.csv")

print("hello df")
"""

dependencies = ["requests", "numpy", "pandas"]

result = execute(code, dependencies, host_path="./temp")
print(result.stdout)
print(f"Exit code: {result.exit_code}")
# Out:
# bind: container: /mounted_data host: C:\structure\code\sand-bob\temp
# hello world 2.3.2
# hello df
#
# Exit code: 0
