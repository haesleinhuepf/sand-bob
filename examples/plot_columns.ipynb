# %%
from sand_bob._code_gen import generate_run

# %%
generate_run("Plot histograms of all columns in input_data/measurements.csv", 
             input_host_path="input_data/", 
             dependencies=["numpy", "seaborn", "matplotlib"])
# Out:
# ...
# ExecutionResult(stdout='[NbConvertApp] Converting notebook notebook.ipynb to notebook\n[NbConvertApp] Writing 112761 bytes to /display_output/notebook_executed.ipynb\n', stderr='', exit_code=0, execution_time=31.623663663864136, container_id='9b1477e8cad4354980f73807111b77dee65ed5f06d5cd2541f5584f12cccea00', code='# Import the required libraries\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport math\n\n# Load the CSV file\ndf = pd.read_csv(\'input_data/measurements.csv\')\n\n# Keep only numeric columns for histogram plotting\nnumeric_df = df.select_dtypes(include=\'number\')\nn_cols = numeric_df.shape[1]\n\n# Determine a reasonable subplot layout (square‑ish)\nn_rows = math.ceil(math.sqrt(n_cols))\nn_fig_cols = math.ceil(n_cols / n_rows)\n\n# Create the figure and axes\nfig, axes = plt.subplots(n_rows, n_fig_cols, figsize=(4 * n_fig_cols, 3 * n_rows))\naxes = axes.flatten()  # simplify indexing\n\n# Plot a histogram for each numeric column\nfor ax, 
# ...

# %%
generate_run("Visualize a coloured correlation matrix of all columns in input_data/measurements.csv", 
             input_host_path="input_data/", 
             dependencies=["numpy", "seaborn", "matplotlib"])
# Out:
# ...
# ExecutionResult(stdout='[NbConvertApp] Converting notebook notebook.ipynb to notebook\n[NbConvertApp] Writing 294383 bytes to /display_output/notebook_executed.ipynb\n', stderr='', exit_code=0, execution_time=30.420907497406006, container_id='70ad1ce7a92f3fba942374abc027e9f151de254d7c7bf2e5e2a85505b50fa938', code='# Import required libraries\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\n# Load the data\ndf = pd.read_csv(\'input_data/measurements.csv\')\n\n# Compute the correlation matrix\ncorr_matrix = df.corr()\n\n# Set up the matplotlib figure\nplt.figure(figsize=(10, 8))\n\n# Draw the heatmap with annotations\nsns.heatmap(\n    corr_matrix,\n    cmap=\'coolwarm\',\n    annot=True,\n    fmt=".2f",\n    linewidths=0.5,\n    cbar_kws={"shrink": .8}\n)\n\n# Add a title for clarity\nplt.title(\'Correlation Matrix of All Columns\', fontsize=14)\nplt.xticks(rotation=45, ha=\'right\')\nplt.yticks(rotation=0)\n\n# ---- Second‑last output: description of th
# ...
