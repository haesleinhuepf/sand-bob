# %%
from sand_bob._results import ExecutionResult, ExecutionResultList
import pandas as pd
import numpy as np

# %%
l = ExecutionResultList([
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=6),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="5"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="wuuu"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=[2,3,34]),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=pd.DataFrame({"a":[2,3], "b":[4,5]})),   
] + [
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=3),
    ]*10
)

l
# Out:
# <div id='sb-list-ce50efcd89b7406d8008c422e540e9d4' class='sb-result-root'>
#
# <style>
# .sb-result-root {
#     --sb-border: #c8c8c8;
#     --sb-tab-bg: #e4e4e4;
#     --sb-tab-hover-bg: #dadada;
#     --sb-active-bg: #ffffff;
#     --sb-content-bg: #ffffff;
#     --sb-text: #2d2d2d;
#     --sb-muted-text: #4a4a4a;
#     --sb-shadow: rgba(0, 0, 0, 0.06);
#     --sb-active-top: #1e6fff;
#     margin-top: 8px;
#     color: var(--sb-text);
#     font-size: 12px;
# }
#
# .sb-history-bar {
#     margin: 0 0 10px 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
# }
#
# .sb-history-label {
#     font-weight: 600;
#     font-size: 13px;
# }
#
# .sb-history-select {
#     min-width: 210px;
#     padding: 4px 8px;
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: #fff;
#     color: var(--sb-text);
# }
#
# .sb-history-panel {
#     margin: 0;
# }
#
# .sb-tabs {
#     border: none;
#     border-radius: 0;
# ...

# %%
l = ExecutionResultList([
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=6),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="5"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="wuuu"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=[2,3,34]),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=pd.DataFrame({"a":[2,3], "b":[4,5]})),   
] + [
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="hello"),
    ]*10
)

l
# Out:
# <div id='sb-list-2f88eea4349a476ca32d3f0705c0c785' class='sb-result-root'>
#
# <style>
# .sb-result-root {
#     --sb-border: #c8c8c8;
#     --sb-tab-bg: #e4e4e4;
#     --sb-tab-hover-bg: #dadada;
#     --sb-active-bg: #ffffff;
#     --sb-content-bg: #ffffff;
#     --sb-text: #2d2d2d;
#     --sb-muted-text: #4a4a4a;
#     --sb-shadow: rgba(0, 0, 0, 0.06);
#     --sb-active-top: #1e6fff;
#     margin-top: 8px;
#     color: var(--sb-text);
#     font-size: 12px;
# }
#
# .sb-history-bar {
#     margin: 0 0 10px 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
# }
#
# .sb-history-label {
#     font-weight: 600;
#     font-size: 13px;
# }
#
# .sb-history-select {
#     min-width: 210px;
#     padding: 4px 8px;
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: #fff;
#     color: var(--sb-text);
# }
#
# .sb-history-panel {
#     margin: 0;
# }
#
# .sb-tabs {
#     border: none;
#     border-radius: 0;
# ...

# %%
l = ExecutionResultList([
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=6),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="5"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="wuuu"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=[2,3,34]),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=pd.DataFrame({"a":[2,3], "b":[4,5]})),   
] + [
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=[2,3,34]),
    ]*10
)

l
# Out:
# <div id='sb-list-89ca86d9563241528ef122d79f3a4d71' class='sb-result-root'>
#
# <style>
# .sb-result-root {
#     --sb-border: #c8c8c8;
#     --sb-tab-bg: #e4e4e4;
#     --sb-tab-hover-bg: #dadada;
#     --sb-active-bg: #ffffff;
#     --sb-content-bg: #ffffff;
#     --sb-text: #2d2d2d;
#     --sb-muted-text: #4a4a4a;
#     --sb-shadow: rgba(0, 0, 0, 0.06);
#     --sb-active-top: #1e6fff;
#     margin-top: 8px;
#     color: var(--sb-text);
#     font-size: 12px;
# }
#
# .sb-history-bar {
#     margin: 0 0 10px 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
# }
#
# .sb-history-label {
#     font-weight: 600;
#     font-size: 13px;
# }
#
# .sb-history-select {
#     min-width: 210px;
#     padding: 4px 8px;
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: #fff;
#     color: var(--sb-text);
# }
#
# .sb-history-panel {
#     margin: 0;
# }
#
# .sb-tabs {
#     border: none;
#     border-radius: 0;
# ...

# %%
l = ExecutionResultList([
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=6),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="5"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="wuuu"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=[2,3,34]),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=pd.DataFrame({"a":[2,3], "b":[4,5]})),   
] + [
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=pd.DataFrame({"c":[2,3], "d":[4,5]})),  
    ]*10
)

l
# Out:
# <div id='sb-list-80e55e3ecc74454b98223098c72692db' class='sb-result-root'>
#
# <style>
# .sb-result-root {
#     --sb-border: #c8c8c8;
#     --sb-tab-bg: #e4e4e4;
#     --sb-tab-hover-bg: #dadada;
#     --sb-active-bg: #ffffff;
#     --sb-content-bg: #ffffff;
#     --sb-text: #2d2d2d;
#     --sb-muted-text: #4a4a4a;
#     --sb-shadow: rgba(0, 0, 0, 0.06);
#     --sb-active-top: #1e6fff;
#     margin-top: 8px;
#     color: var(--sb-text);
#     font-size: 12px;
# }
#
# .sb-history-bar {
#     margin: 0 0 10px 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
# }
#
# .sb-history-label {
#     font-weight: 600;
#     font-size: 13px;
# }
#
# .sb-history-select {
#     min-width: 210px;
#     padding: 4px 8px;
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: #fff;
#     color: var(--sb-text);
# }
#
# .sb-history-panel {
#     margin: 0;
# }
#
# .sb-tabs {
#     border: none;
#     border-radius: 0;
# ...

# %%
l = ExecutionResultList([
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=6),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="5"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="wuuu"),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=[2,3,34]),
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result=pd.DataFrame({"a":[2,3], "b":[4,5]})),   
] + [
    ExecutionResult(stdout="", stderr="", exit_code=0, execution_time=5, final_result="hello"),
    ]*10
)

l
# Out:
# <div id='sb-list-f2f6a67aad7443d6b32e96c348b07afa' class='sb-result-root'>
#
# <style>
# .sb-result-root {
#     --sb-border: #c8c8c8;
#     --sb-tab-bg: #e4e4e4;
#     --sb-tab-hover-bg: #dadada;
#     --sb-active-bg: #ffffff;
#     --sb-content-bg: #ffffff;
#     --sb-text: #2d2d2d;
#     --sb-muted-text: #4a4a4a;
#     --sb-shadow: rgba(0, 0, 0, 0.06);
#     --sb-active-top: #1e6fff;
#     margin-top: 8px;
#     color: var(--sb-text);
#     font-size: 12px;
# }
#
# .sb-history-bar {
#     margin: 0 0 10px 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
# }
#
# .sb-history-label {
#     font-weight: 600;
#     font-size: 13px;
# }
#
# .sb-history-select {
#     min-width: 210px;
#     padding: 4px 8px;
#     border: 1px solid var(--sb-border);
#     border-radius: 4px;
#     background: #fff;
#     color: var(--sb-text);
# }
#
# .sb-history-panel {
#     margin: 0;
# }
#
# .sb-tabs {
#     border: none;
#     border-radius: 0;
# ...

# %%
l.display_result_summary()
